# %%
import campanhas as cp
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta
import perfil as pf

# %%
usuario = 'flavia-costa'
chave = 'cpf' #ou cpf ou conta_cartao
path_campanha = 'marketing/campanhas_participantes/'
arquivo_campanha = 'fake_natal.csv'
dt_ini = '2021-12-13'
dt_fim = '2021-12-20'

# %%
# %%time
cp.relatorio_campanhas('flavia-costa', dt_ini, dt_fim, chave, path_campanha, arquivo_campanha, ';')
# Out:
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 18:22: mismatched input 'pag'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
#            grupo converteu    spending               transacoes
#            count      mean        mean           sum       mean        sum
# grupo
# alvo      865733  0.438616  444.877431  1.689306e+08   3.690562  1401395.0
# controle   28873  0.262494  417.647348  3.165349e+06   3.831640    29040.0
# _____________________
# Lift da conversão: 67.1%
# Estatística t do teste de diferença de proporções: 59.53
# P-valor do teste de diferença de proporções: 0.0
# Conclusão:
# A diferença de conversão é estatisticamente significativa
# ______________________________________________________________
# Lift do spending: 6.52%
# Estatística t do teste de spending: 27.57
# P-valor do teste de spending: 0.0
# Conclusão:
# A diferença de spending é estatisticamente significativa
# ______________________________________________________________
# Lift da frequência: -3.68%
# Estatística t do teste de frequencia: 33.36
# P-valor do teste de frequencia: 0.0
# A diferença de frequência é estatisticamente significativa
# ______________________________________________________________
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 18:22: mismatched input 'pag'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 18:22: mismatched input 'pag'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 25:52: mismatched input 'C'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
# ___________________________________________
# Distribuição de Frequência Antes x Depois
# g. Sem compras          0.479244
# f. Mais de 5 compras    0.142531
# a. 1 compra             0.140575
# b. 2 compras            0.090685
# c. 3 compras            0.064000
# d. 4 compras            0.047347
# e. 5 compras            0.035618
# Name: fx_frequencia_antes, dtype: float64
# g. Sem compras          0.567069
# a. 1 compra             0.142444
# f. Mais de 5 compras    0.086890
# b. 2 compras            0.083042
# c. 3 compras            0.054650
# d. 4 compras            0.038283
# e. 5 compras            0.027623
# Name: fx_frequencia, dtype: float64
# ___________________________________________
# Distribuição de Spending Antes x Depois
# f. Sem compras        0.479244
# a. até R$ 300         0.277438
# b. até R$ 600         0.107320
# c. até R$ 1000        0.065748
# e. mais de R$ 1500    0.036036
# d. até R$ 1500        0.034213
# Name: fx_spending_antes, dtype: float64
# f. Sem compras        0.567069
# a. até R$ 300         0.257157
# b. até R$ 600         0.082134
# c. até R$ 1000        0.045029
# e. mais de R$ 1500    0.025221
# d. até R$ 1500        0.023390
# Name: fx_spending, dtype: float64
# ___________________________________________
# conversão por faixa anterior de frequencia e spending
#                      fx_frequencia_antes converteu    spending                \
#                                    count      mean        mean           sum
# fx_frequencia_antes
# a. 1 compra                       123519  0.460018  430.974012  2.448837e+07
# b. 2 compras                       79742  0.561799  398.886132  1.786970e+07
# c. 3 compras                       56229  0.628377  389.742658  1.377078e+07
# d. 4 compras                       41594  0.667356  383.725435  1.065145e+07
# e. 5 compras                       31216  0.711814  385.005310  8.554818e+06
# f. Mais de 5 compras              124812  0.803360  443.970560  4.451648e+07
# g. Sem compras                    408621  0.226430  530.446517  4.907903e+07
#
#                      transacoes
#                            mean       sum
# fx_frequencia_antes
# a. 1 compra            2.682723  152435.0
# b. 2 compras           2.957722  132503.0
# c. 3 compras           3.177822  112282.0
# d. 4 compras           3.506232   97326.0
# e. 5 compras           3.795230   84330.0
# f. Mais de 5 compras   5.719744  573513.0
# g. Sem compras         2.691258  249006.0
# _____________________
#                    fx_spending_antes converteu    spending                \
#                                count      mean        mean           sum
# fx_spending_antes
# a. até R$ 300                 243497  0.609597  361.509666  5.366069e+07
# b. até R$ 600                  94221  0.657613  391.973788  2.428709e+07
# c. até R$ 1000                 57714  0.652511  454.089447  1.710055e+07
# d. até R$ 1500                 30072  0.646582  553.650656  1.076518e+07
# e. mais de R$ 1500             31608  0.623292  712.557287  1.403809e+07
# f. Sem compras                408621  0.226430  530.446517  4.907903e+07
#
#                    transacoes
#                          mean       sum
# fx_spending_antes
# a. até R$ 300        3.508014  520712.0
# b. até R$ 600        4.214764  261151.0
# c. até R$ 1000       4.591519  172912.0
# d. até R$ 1500       4.961016   96462.0
# e. mais de R$ 1500   5.134359  101152.0
# f. Sem compras       2.691258  249006.0
# _____________________
# conversão por limite disponível
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 18:22: mismatched input 'pag'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
#                    fx_limite converteu    spending               transacoes  \
#                        count      mean        mean           sum       mean
# fx_limite
# a. até R$ 100          76097  0.546355  395.402442  1.643925e+07   4.406100
# b. até R$ 300          73892  0.605275  263.199922  1.177162e+07   3.684897
# c. até R$ 600          82784  0.651744  302.221858  1.630608e+07   3.897987
# d. até R$ 1000         68469  0.660255  379.974245  1.717750e+07   4.073042
# e. até R$ 1500         46866  0.657150  465.145990  1.432557e+07   4.134035
# f. mais de R$ 1500    109004  0.650802  617.868562  4.383160e+07   3.984099
# g. Sem info           408621  0.226430  530.446517  4.907903e+07   2.691258
#
#
#                          sum
# fx_limite
# a. até R$ 100       183188.0
# b. até R$ 300       164807.0
# c. até R$ 600       210312.0
# d. até R$ 1000      184130.0
# e. até R$ 1500      127320.0
# f. mais de R$ 1500  282632.0
# g. Sem info         249006.0
# _____________________
# conversão por faixa de recência
#                     fx_recencia converteu    spending                \
#                           count      mean        mean           sum
# fx_recencia
# a. menos 1 mes           588326  0.582261  430.076025  1.473264e+08
# b. 1 mes                  86746  0.227192  541.097643  1.066395e+07
# c. 2 meses                36873  0.119030  603.409925  2.648366e+06
# d. 3 meses                19051  0.104666  730.371605  1.456361e+06
# e. 4 meses                13472  0.078607  802.317602  8.496543e+05
# f. 5 meses                10331  0.072210  833.894625  6.220854e+05
# g. 6 meses                 8406  0.052700  901.025079  3.991541e+05
# h. 7 meses                 6612  0.048699  875.451429  2.818954e+05
# i. 8 meses                 5057  0.045877  793.846767  1.841724e+05
# j. 9 meses                 4703  0.037848  965.864382  1.719239e+05
# k. 10 meses                3997  0.034526  857.987246  1.184022e+05
# l. 11 meses                4290  0.030536  866.459771  1.135062e+05
# m. mais de 12 meses       37606  0.014865  777.320572  4.345222e+05
# n. sem transacao          40263  0.180463  503.747442  3.660229e+06
#
#                     transacoes
#                           mean        sum
# fx_recencia
# a. menos 1 mes        3.817809  1307825.0
# b. 1 mes              2.370357    46715.0
# c. 2 meses            2.075644     9110.0
# d. 3 meses            2.074223     4136.0
# e. 4 meses            2.024551     2144.0
# f. 5 meses            2.021448     1508.0
# g. 6 meses            2.097065      929.0
# h. 7 meses            2.149068      692.0
# i. 8 meses            1.943966      451.0
# j. 9 meses            2.095506      373.0
# k. 10 meses           2.275362      314.0
# l. 11 meses           2.793893      366.0
# m. mais de 12 meses   2.590340     1448.0
# n. sem transacao      3.493532    25384.0
# _____________________
# Distribuição de atraso nos clientes com conversão:
# A - Até 5 dias atraso    0.999445
# B - 5 a 10 dias          0.000323
# C - Mais de 10 dias      0.000232
# Name: fx_atraso, dtype: float64
# Distribuição de atraso nos clientes sem conversão:
# Failed to execute query.
# Traceback (most recent call last):
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/pyathena/common.py", line 307, in _execute
#     query_id = retry_api_call(
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/pyathena/util.py", line 84, in retry_api_call
#     return retry(func, *args, **kwargs)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/tenacity/__init__.py", line 430, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/tenacity/__init__.py", line 367, in iter
#     return fut.result()
#   File "/usr/lib/python3.9/concurrent/futures/_base.py", line 433, in result
#     return self.__get_result()
#   File "/usr/lib/python3.9/concurrent/futures/_base.py", line 389, in __get_result
#     raise self._exception
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/tenacity/__init__.py", line 433, in __call__
#     result = fn(*args, **kwargs)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/botocore/client.py", line 357, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/botocore/client.py", line 676, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 20:60: mismatched input 'C'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
# A - Até 5 dias atraso    0.997469
# C - Mais de 10 dias      0.001946
# B - 5 a 10 dias          0.000585
# Name: fx_atraso, dtype: float64
# ________________Segmentação RFV___________________
# _____________________
# ________________Análises de perfil___________________
# converteu       0.0       1.0       All
# pf_genero
# MALE       0.577866  0.501431  0.550753
# FEMALE     0.416451  0.492292  0.443353
#            0.005683  0.006277  0.005894
# _______________________________________
# converteu             0.0       1.0       All
# pf_faixa_idade
# b - 25-34 anos   0.387680  0.346349  0.373019
# a - ate 24 anos  0.241133  0.315610  0.267551
# c - 35-44 anos   0.229360  0.192467  0.216274
# d - 45-54 anos   0.095093  0.097480  0.095940
# e - 55-64 anos   0.035267  0.035724  0.035429
# f - 65-74 anos   0.009032  0.008770  0.008939
# h - idade NI     0.001979  0.003231  0.002423
# g - 75-84 anos   0.000457  0.000369  0.000426
# _______________________________________
# converteu       0.0       1.0       All
# pf_estado
# BA         0.141106  0.163657  0.149099
# SP         0.136378  0.094934  0.121689
# PE         0.108919  0.113828  0.110659
# CE         0.096461  0.103640  0.099005
# MG         0.076223  0.069649  0.073893
# RJ         0.058222  0.054182  0.056790
# ES         0.047341  0.059739  0.051735
# RN         0.043069  0.051311  0.045990
# PB         0.039510  0.041678  0.040278
# AL         0.038137  0.043068  0.039884
# GO         0.029238  0.031490  0.030036
# MA         0.025679  0.024822  0.025375
# PA         0.023797  0.026211  0.024653
# PR         0.025475  0.019172  0.023241
# SE         0.020340  0.022414  0.021075
# RS         0.019526  0.014912  0.017891
# PI         0.016729  0.017134  0.016873
# SC         0.016475  0.012967  0.015232
# DF         0.010627  0.008428  0.009848
# AM         0.005543  0.005928  0.005679
# MT         0.005746  0.005094  0.005515
# MS         0.004678  0.004075  0.004464
# TO         0.003763  0.004724  0.004103
# RO         0.003356  0.003890  0.003545
# AP         0.001627  0.001389  0.001543
# AC         0.001322  0.001111  0.001247
# RR         0.000712  0.000556  0.000657
# _______________________________________
# converteu          0.0       1.0       All
# pf_regiao
# NORDESTE      0.528848  0.579618  0.546857
# SUDESTE       0.317501  0.277578  0.303340
# SUL           0.061349  0.046894  0.056221
# CENTRO-OESTE  0.050185  0.048925  0.049738
# NORTE         0.040037  0.043663  0.041323
# Z-OUTROS      0.002080  0.003323  0.002521
# _______________________________________
# converteu             0.0       1.0       All
# pf_estado_civil
# Solteiro         0.648653  0.681344  0.660249
# Casado           0.266606  0.233915  0.255010
# Divorciado       0.043487  0.041447  0.042764
# Outros           0.031106  0.030555  0.030910
# Viuvo            0.007916  0.009046  0.008317
# outros           0.002233  0.003692  0.002750
# _______________________________________
# converteu                               0.0       1.0       All
# pf_escolaridade
# d - Ensino médio completo          0.429741  0.463171  0.441588
# e - Ensino superior incompleto     0.171591  0.175855  0.173102
# f - Ensino superior completo       0.150130  0.123043  0.140531
# b - Ensino fundamental completo    0.059859  0.065227  0.061761
# a - Ensino fundamental incompleto  0.060977  0.062818  0.061630
# c - Ensino médio incompleto        0.049840  0.060873  0.053750
# h - Pós graduação completa         0.043584  0.024924  0.036971
# g - Pós graduação incompleta       0.017342  0.011952  0.015432
# m - Outros                         0.005696  0.006300  0.005910
# j - Mestrado completo              0.004730  0.002780  0.004039
# i - Mestrado incompleto            0.003153  0.001668  0.002627
# l - Doutorado completo             0.001933  0.000649  0.001478
# k - Doutorado incompleto           0.001424  0.000741  0.001182
# _______________________________________
# converteu                    0.0       1.0       All
# pf_idade_conta
# b - 1-2 anos de conta   0.650632  0.655128  0.652227
# a - ate 1 ano de conta  0.179479  0.247577  0.203635
# c - 2-3 anos de conta   0.071751  0.047171  0.063032
# d - 3-4 anos de conta   0.073172  0.036924  0.060314
# e - 4-5 anos de conta   0.023900  0.012739  0.019941
# f - 5-6 anos de conta   0.001066  0.000462  0.000851
# _______________________________________
# converteu                     0.0       1.0       All
# pf_renda_declarada_will
# B - ate R$ 2000          0.335834  0.408024  0.363221
# C - ate R$ 3000          0.226269  0.234808  0.229509
# F - mais de R$ 5000      0.190061  0.120708  0.163749
# D - ate R$ 4000          0.110574  0.098053  0.105824
# E - ate R$ 5000          0.098673  0.089204  0.095080
# A - ate R$ 1000          0.038589  0.049204  0.042616
# _______________________________________
# As combinações com maior lift de conversão serão salvas no arquivo report_perfil_total.csv
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# CPU times: user 5min 2s, sys: 16.9 s, total: 5min 19s
# Wall time: 29min 1s

# %%
# %%time
cp.relatorio_campanhas_sem_grafico('flavia-costa', dt_ini, dt_fim, chave, path_campanha, arquivo_campanha, ';')
# Out:
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 18:22: mismatched input 'pag'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
#            grupo converteu    spending               transacoes
#            count      mean        mean           sum       mean        sum
# grupo
# alvo      865733  0.438616  444.877431  1.689306e+08   3.690562  1401395.0
# controle   28873  0.262494  417.647348  3.165349e+06   3.831640    29040.0
# _____________________
# Lift da conversão: 67.1%
# Estatística t do teste de diferença de proporções: 59.53
# P-valor do teste de diferença de proporções: 0.0
# Conclusão:
# A diferença de conversão é estatisticamente significativa
# ______________________________________________________________
# Lift do spending: 6.52%
# Estatística t do teste de spending: 27.57
# P-valor do teste de spending: 0.0
# Conclusão:
# A diferença de spending é estatisticamente significativa
# ______________________________________________________________
# Lift da frequência: -3.68%
# Estatística t do teste de frequencia: 33.36
# P-valor do teste de frequencia: 0.0
# A diferença de frequência é estatisticamente significativa
# ______________________________________________________________
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 25:52: mismatched input 'C'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
# ___________________________________________
# Distribuição de Frequência Antes x Depois
# g. Sem compras          0.479244
# f. Mais de 5 compras    0.142531
# a. 1 compra             0.140575
# b. 2 compras            0.090685
# c. 3 compras            0.064000
# d. 4 compras            0.047347
# e. 5 compras            0.035618
# Name: fx_frequencia_antes, dtype: float64
# g. Sem compras          0.567069
# a. 1 compra             0.142444
# f. Mais de 5 compras    0.086890
# b. 2 compras            0.083042
# c. 3 compras            0.054650
# d. 4 compras            0.038283
# e. 5 compras            0.027623
# Name: fx_frequencia, dtype: float64
# ___________________________________________
# Distribuição de Spending Antes x Depois
# f. Sem compras        0.479244
# a. até R$ 300         0.277438
# b. até R$ 600         0.107320
# c. até R$ 1000        0.065748
# e. mais de R$ 1500    0.036036
# d. até R$ 1500        0.034213
# Name: fx_spending_antes, dtype: float64
# f. Sem compras        0.567069
# a. até R$ 300         0.257157
# b. até R$ 600         0.082134
# c. até R$ 1000        0.045029
# e. mais de R$ 1500    0.025221
# d. até R$ 1500        0.023390
# Name: fx_spending, dtype: float64
# ___________________________________________
# conversão por faixa anterior de frequencia e spending
#                      fx_frequencia_antes converteu    spending                \
#                                    count      mean        mean           sum
# fx_frequencia_antes
# a. 1 compra                       123519  0.460018  430.974012  2.448837e+07
# b. 2 compras                       79742  0.561799  398.886132  1.786970e+07
# c. 3 compras                       56229  0.628377  389.742658  1.377078e+07
# d. 4 compras                       41594  0.667356  383.725435  1.065145e+07
# e. 5 compras                       31216  0.711814  385.005310  8.554818e+06
# f. Mais de 5 compras              124812  0.803360  443.970560  4.451648e+07
# g. Sem compras                    408621  0.226430  530.446517  4.907903e+07
#
#                      transacoes
#                            mean       sum
# fx_frequencia_antes
# a. 1 compra            2.682723  152435.0
# b. 2 compras           2.957722  132503.0
# c. 3 compras           3.177822  112282.0
# d. 4 compras           3.506232   97326.0
# e. 5 compras           3.795230   84330.0
# f. Mais de 5 compras   5.719744  573513.0
# g. Sem compras         2.691258  249006.0
# _____________________
#                    fx_spending_antes converteu    spending                \
#                                count      mean        mean           sum
# fx_spending_antes
# a. até R$ 300                 243497  0.609597  361.509666  5.366069e+07
# b. até R$ 600                  94221  0.657613  391.973788  2.428709e+07
# c. até R$ 1000                 57714  0.652511  454.089447  1.710055e+07
# d. até R$ 1500                 30072  0.646582  553.650656  1.076518e+07
# e. mais de R$ 1500             31608  0.623292  712.557287  1.403809e+07
# f. Sem compras                408621  0.226430  530.446517  4.907903e+07
#
#                    transacoes
#                          mean       sum
# fx_spending_antes
# a. até R$ 300        3.508014  520712.0
# b. até R$ 600        4.214764  261151.0
# c. até R$ 1000       4.591519  172912.0
# d. até R$ 1500       4.961016   96462.0
# e. mais de R$ 1500   5.134359  101152.0
# f. Sem compras       2.691258  249006.0
# _____________________
# conversão por limite disponível
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 18:22: mismatched input 'pag'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
#                    fx_limite converteu    spending               transacoes  \
#                        count      mean        mean           sum       mean
# fx_limite
# a. até R$ 100          76097  0.546355  395.402442  1.643925e+07   4.406100
# b. até R$ 300          73892  0.605275  263.199922  1.177162e+07   3.684897
# c. até R$ 600          82784  0.651744  302.221858  1.630608e+07   3.897987
# d. até R$ 1000         68469  0.660255  379.974245  1.717750e+07   4.073042
# e. até R$ 1500         46866  0.657150  465.145990  1.432557e+07   4.134035
# f. mais de R$ 1500    109004  0.650802  617.868562  4.383160e+07   3.984099
# g. Sem info           408621  0.226430  530.446517  4.907903e+07   2.691258
#
#
#                          sum
# fx_limite
# a. até R$ 100       183188.0
# b. até R$ 300       164807.0
# c. até R$ 600       210312.0
# d. até R$ 1000      184130.0
# e. até R$ 1500      127320.0
# f. mais de R$ 1500  282632.0
# g. Sem info         249006.0
# _____________________
# conversão por faixa de recência
#                     fx_recencia converteu    spending                \
#                           count      mean        mean           sum
# fx_recencia
# a. menos 1 mes           588326  0.582261  430.076025  1.473264e+08
# b. 1 mes                  86746  0.227192  541.097643  1.066395e+07
# c. 2 meses                36873  0.119030  603.409925  2.648366e+06
# d. 3 meses                19051  0.104666  730.371605  1.456361e+06
# e. 4 meses                13472  0.078607  802.317602  8.496543e+05
# f. 5 meses                10331  0.072210  833.894625  6.220854e+05
# g. 6 meses                 8406  0.052700  901.025079  3.991541e+05
# h. 7 meses                 6612  0.048699  875.451429  2.818954e+05
# i. 8 meses                 5057  0.045877  793.846767  1.841724e+05
# j. 9 meses                 4703  0.037848  965.864382  1.719239e+05
# k. 10 meses                3997  0.034526  857.987246  1.184022e+05
# l. 11 meses                4290  0.030536  866.459771  1.135062e+05
# m. mais de 12 meses       37606  0.014865  777.320572  4.345222e+05
# n. sem transacao          40263  0.180463  503.747442  3.660229e+06
#
#                     transacoes
#                           mean        sum
# fx_recencia
# a. menos 1 mes        3.817809  1307825.0
# b. 1 mes              2.370357    46715.0
# c. 2 meses            2.075644     9110.0
# d. 3 meses            2.074223     4136.0
# e. 4 meses            2.024551     2144.0
# f. 5 meses            2.021448     1508.0
# g. 6 meses            2.097065      929.0
# h. 7 meses            2.149068      692.0
# i. 8 meses            1.943966      451.0
# j. 9 meses            2.095506      373.0
# k. 10 meses           2.275362      314.0
# l. 11 meses           2.793893      366.0
# m. mais de 12 meses   2.590340     1448.0
# n. sem transacao      3.493532    25384.0
# _____________________
# Distribuição de atraso nos clientes com conversão:
# A - Até 5 dias atraso    0.999445
# B - 5 a 10 dias          0.000323
# C - Mais de 10 dias      0.000232
# Name: fx_atraso, dtype: float64
# Distribuição de atraso nos clientes sem conversão:
# A - Até 5 dias atraso    0.997469
# C - Mais de 10 dias      0.001946
# B - 5 a 10 dias          0.000585
# Name: fx_atraso, dtype: float64
# _____________________
# ________________Análises de perfil___________________
# Failed to execute query.
# Traceback (most recent call last):
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/pyathena/common.py", line 307, in _execute
#     query_id = retry_api_call(
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/pyathena/util.py", line 84, in retry_api_call
#     return retry(func, *args, **kwargs)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/tenacity/__init__.py", line 430, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/tenacity/__init__.py", line 367, in iter
#     return fut.result()
#   File "/usr/lib/python3.9/concurrent/futures/_base.py", line 433, in result
#     return self.__get_result()
#   File "/usr/lib/python3.9/concurrent/futures/_base.py", line 389, in __get_result
#     raise self._exception
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/tenacity/__init__.py", line 433, in __call__
#     result = fn(*args, **kwargs)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/botocore/client.py", line 357, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/home/flavia.costa/.local/lib/python3.9/site-packages/botocore/client.py", line 676, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 20:60: mismatched input 'C'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
# converteu       0.0       1.0       All
# pf_genero
# MALE       0.577866  0.501431  0.550753
# FEMALE     0.416451  0.492292  0.443353
#            0.005683  0.006277  0.005894
# _______________________________________
# converteu             0.0       1.0       All
# pf_faixa_idade
# b - 25-34 anos   0.387680  0.346349  0.373019
# a - ate 24 anos  0.241133  0.315610  0.267551
# c - 35-44 anos   0.229360  0.192467  0.216274
# d - 45-54 anos   0.095093  0.097480  0.095940
# e - 55-64 anos   0.035267  0.035724  0.035429
# f - 65-74 anos   0.009032  0.008770  0.008939
# h - idade NI     0.001979  0.003231  0.002423
# g - 75-84 anos   0.000457  0.000369  0.000426
# _______________________________________
# converteu       0.0       1.0       All
# pf_estado
# BA         0.141106  0.163657  0.149099
# SP         0.136378  0.094934  0.121689
# PE         0.108919  0.113828  0.110659
# CE         0.096461  0.103640  0.099005
# MG         0.076223  0.069649  0.073893
# RJ         0.058222  0.054182  0.056790
# ES         0.047341  0.059739  0.051735
# RN         0.043069  0.051311  0.045990
# PB         0.039510  0.041678  0.040278
# AL         0.038137  0.043068  0.039884
# GO         0.029238  0.031490  0.030036
# MA         0.025679  0.024822  0.025375
# PA         0.023797  0.026211  0.024653
# PR         0.025475  0.019172  0.023241
# SE         0.020340  0.022414  0.021075
# RS         0.019526  0.014912  0.017891
# PI         0.016729  0.017134  0.016873
# SC         0.016475  0.012967  0.015232
# DF         0.010627  0.008428  0.009848
# AM         0.005543  0.005928  0.005679
# MT         0.005746  0.005094  0.005515
# MS         0.004678  0.004075  0.004464
# TO         0.003763  0.004724  0.004103
# RO         0.003356  0.003890  0.003545
# AP         0.001627  0.001389  0.001543
# AC         0.001322  0.001111  0.001247
# RR         0.000712  0.000556  0.000657
# _______________________________________
# converteu          0.0       1.0       All
# pf_regiao
# NORDESTE      0.528848  0.579618  0.546857
# SUDESTE       0.317501  0.277578  0.303340
# SUL           0.061349  0.046894  0.056221
# CENTRO-OESTE  0.050185  0.048925  0.049738
# NORTE         0.040037  0.043663  0.041323
# Z-OUTROS      0.002080  0.003323  0.002521
# _______________________________________
# converteu             0.0       1.0       All
# pf_estado_civil
# Solteiro         0.648653  0.681344  0.660249
# Casado           0.266606  0.233915  0.255010
# Divorciado       0.043487  0.041447  0.042764
# Outros           0.031106  0.030555  0.030910
# Viuvo            0.007916  0.009046  0.008317
# outros           0.002233  0.003692  0.002750
# _______________________________________
# converteu                               0.0       1.0       All
# pf_escolaridade
# d - Ensino médio completo          0.429741  0.463171  0.441588
# e - Ensino superior incompleto     0.171591  0.175855  0.173102
# f - Ensino superior completo       0.150130  0.123043  0.140531
# b - Ensino fundamental completo    0.059859  0.065227  0.061761
# a - Ensino fundamental incompleto  0.060977  0.062818  0.061630
# c - Ensino médio incompleto        0.049840  0.060873  0.053750
# h - Pós graduação completa         0.043584  0.024924  0.036971
# g - Pós graduação incompleta       0.017342  0.011952  0.015432
# m - Outros                         0.005696  0.006300  0.005910
# j - Mestrado completo              0.004730  0.002780  0.004039
# i - Mestrado incompleto            0.003153  0.001668  0.002627
# l - Doutorado completo             0.001933  0.000649  0.001478
# k - Doutorado incompleto           0.001424  0.000741  0.001182
# _______________________________________
# converteu                    0.0       1.0       All
# pf_idade_conta
# b - 1-2 anos de conta   0.650632  0.655128  0.652227
# a - ate 1 ano de conta  0.179479  0.247577  0.203635
# c - 2-3 anos de conta   0.071751  0.047171  0.063032
# d - 3-4 anos de conta   0.073172  0.036924  0.060314
# e - 4-5 anos de conta   0.023900  0.012739  0.019941
# f - 5-6 anos de conta   0.001066  0.000462  0.000851
# _______________________________________
# converteu                     0.0       1.0       All
# pf_renda_declarada_will
# B - ate R$ 2000          0.335834  0.408024  0.363221
# C - ate R$ 3000          0.226269  0.234808  0.229509
# F - mais de R$ 5000      0.190061  0.120708  0.163749
# D - ate R$ 4000          0.110574  0.098053  0.105824
# E - ate R$ 5000          0.098673  0.089204  0.095080
# A - ate R$ 1000          0.038589  0.049204  0.042616
# _______________________________________
# As combinações com maior lift de conversão serão salvas no arquivo report_perfil_total.csv
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# report dos perfis finalizado!
# CPU times: user 3min 38s, sys: 11.4 s, total: 3min 50s
# Wall time: 20min 3s
