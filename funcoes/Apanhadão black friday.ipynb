# %%
import campanhas as cp
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta
import perfil as pf

# %%
usuario = 'flavia-costa'
# path_campanha = 'marketing/bases_campanha_2021/'
# arquivo_campanha = '202111_pagamarelo_incentivo_shopee_blackfriday.csv'

# path_campanha = 'marketing/bases_campanha_2021/'
# arquivo_campanha = '202111_pagamarelo_aumento_limite_geral.csv'
# dt_ini = '2021-11-05'
# dt_fim = '2021-11-12'
# chave = 'conta_cartao' #ou cpf ou conta_cartao

# path_campanha = 'marketing/bases_campanha_2021_will/'
# arquivo_campanha = '202111_will_incentivo_shopee_blackfriday.csv'
# dt_ini = '2021-11-11'
# dt_fim = '2021-11-18'
# chave = 'cpf' #ou cpf ou conta_cartao

path_campanha = 'marketing/campanhas_participantes/'
arquivo_campanha = 'fake_bf.csv'
dt_ini = '2021-11-22'
dt_fim = '2021-11-29'
chave = 'cpf' #ou cpf ou conta_cartao

# %%
# %%time
cp.relatorio_campanhas('flavia-costa', dt_ini, dt_fim, chave, path_campanha, arquivo_campanha, ';')
# Out:
# Failed to execute query.
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 18:22: mismatched input 'pag'. Expecting: '%', '*', '+', '-', '.', '/', 'AND', 'AT', 'EXCEPT', 'GROUP', 'HAVING', 'INTERSECT', 'LIMIT', 'OFFSET', 'OR', 'ORDER', 'UNION', '[', '||', <EOF>
#             grupo converteu    spending               transacoes
#             count      mean        mean           sum       mean        sum
# grupo
# alvo      1069651  0.369433  414.678678  1.638661e+08   3.436596  1358019.0
# controle     3500  0.222857  326.986897  2.550498e+05   3.365385     2625.0
# _____________________
# Lift da conversão: 65.77%
# Estatística t do teste de diferença de proporções: 17.94
# P-valor do teste de diferença de proporções: 0.0
# Conclusão:
# A diferença de conversão é estatisticamente significativa
# ______________________________________________________________
# Lift do spending: 26.82%
# ...
